# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
train = pd.read_csv('../moblie_data/train_clean_cutdup.csv')
test = pd.read_csv('../moblie_data/test_clean.csv')
train = train.iloc[:,1:]
test = test.iloc[:,1:]

# %%
train.shape
# Out:
# (536488, 27)

# %%
test.shape
# Out:
# (262565, 26)

# %%
train.drop_duplicates(subset=list(train.columns)[:-2]).shape
# Out:
# (536488, 27)

# %%
test.drop_duplicates(subset=list(test.columns)[:-1]).shape
# Out:
# (255065, 26)

# %%
train.head()
# Out:
#    service_type  is_mix_service  online_time  1_total_fee  2_total_fee  \
# 0             4               0           85       295.96       296.20
# 1             1               0           10       265.20       261.20
# 2             1               0           12        44.50        70.20
# 3             4               0          134        87.95        81.40
# 4             4               0           84       317.04       314.08
#
#    3_total_fee  4_total_fee  month_traffic  many_over_bill  contract_type  \
# 0       296.00       296.80    3813.614698               0              1
# 1       208.50       174.50       0.000000               1              0
# 2        69.00        61.40    2598.397406               0              0
# 3        76.00        88.30     988.440563               0              0
# 4       435.51       413.05    5885.800642               0              1
#
#          ...         local_caller_time  service1_caller_time  \
# ...

# %%
test.head()
# Out:
#    service_type  is_mix_service  online_time  1_total_fee  2_total_fee  \
# 0             4               0          193        80.00        80.00
# 1             1               0            5        86.70        74.20
# 2             4               0           62        90.90       127.35
# 3             4               0           87        95.45       154.65
# 4             4               0           53        76.00        86.00
#
#    3_total_fee  4_total_fee  month_traffic  many_over_bill  contract_type  \
# 0        80.00        80.00     872.042338               0              0
# 1        57.10        68.90     200.000000               1              0
# 2        82.60        91.00   22927.945140               0              9
# 3        75.95       143.35    4793.146457               0              1
# 4        76.00        76.00     563.253649               0              0
#
#          ...         local_trafffic_month  local_caller_time  \
# ...

# %%
train_test_dup = pd.merge(train, test, how='inner', on=list(train.columns)[:-2])

# %%
train_test_dup.shape
# Out:
# (1749, 28)

# %%
train_test_dup.drop_duplicates(subset='user_id_x').iloc[:,-3:].to_csv('../moblie_data/duplicate.csv')

# %%
train_test_dup
# Out:
#       service_type  is_mix_service  online_time  1_total_fee  2_total_fee  \
# 0                1               0           12        60.00        80.60
# 1                1               0            6        29.50        28.80
# 2                1               0           53        44.00        49.40
# 3                4               1           76       166.00       166.00
# 4                4               0            8       105.92        69.00
# 5                1               0            5        43.10        21.52
# 6                1               0            6        36.00        33.80
# 7                1               0           18       141.70       172.90
# 8                4               0           11        21.00        21.00
# 9                4               0           23        16.00         0.00
# 10               4               0           70        16.20        16.00
# 11               1               0            4        91.30        68.39
# ...
